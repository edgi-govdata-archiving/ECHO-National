# %% [markdown]
# | ![EEW logo](https://github.com/edgi-govdata-archiving/EEW-Image-Assets/blob/master/Jupyter%20instructions/eew.jpg?raw=true) | ![EDGI logo](https://github.com/edgi-govdata-archiving/EEW-Image-Assets/blob/master/Jupyter%20instructions/edgi.png?raw=true) |
# |---|---|
#
# #### This notebook is licensed under GPL 3.0. Please visit our Github repo for more information:  https://github.com/edgi-govdata-archiving/ECHO-Cross-Program
# #### The notebook was collaboratively authored by the Environmental Data & Governance Initiative (EDGI) following our authorship protocol: https://docs.google.com/document/d/1CtDN5ZZ4Zv70fHiBTmWkDJ9mswEipX6eCYrwicP66Xw/
# #### For more information about this project, visit https://www.environmentalenforcementwatch.org/

# %% [markdown]
# ## How to Run this Notebook
# * If you click on a gray **code** cell, a little “play button” arrow appears on the left. If you click the play button, it will run the code in that cell (“**running** a cell”). The button will animate. When the animation stops, the cell has finished running.
# ![Where to click to run the cell](https://github.com/edgi-govdata-archiving/EEW-Image-Assets/blob/master/Jupyter%20instructions/pressplay.JPG?raw=true)
# * You may get a warning that the notebook was not authored by Google. We know, we authored them! It’s okay. Click “Run Anyway” to continue.
# ![Error Message](https://github.com/edgi-govdata-archiving/EEW-Image-Assets/blob/master/Jupyter%20instructions/warning-message.JPG?raw=true)
# * Run all of the cells in a Notebook to make a complete report. Please feel free to look at and **learn about each result as you create it**!
#
# ---

# %% [markdown]
# # Nationwide statistics about environmental enforcement and compliance trends

# %% [markdown]
# ## Setup
# Here we load some helper code to get us going.

# %%
# Import code libraries
# !pip install ECHO_modules &>/dev/null;
# !pip install geopandas &>/dev/null;

import urllib.parse
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import requests
import csv
import datetime
import folium
from folium.plugins import FastMarkerCluster
import ipywidgets as widgets
from IPython.core.display import display, HTML
from pandas.errors import EmptyDataError
from ECHO_modules.get_data import get_echo_data

def formatter(value):
  return "{:0.2f}".format(value)

print("Done!")
# Out:
# Done!

# %% [markdown]
# Here we set up some code to help us store and eventually export the metrics.

# %%
inspections = dict()
violations = dict()
enforcements = dict()
penalties = dict()
emissions = dict()

# %% [markdown]
# ## Start getting data
# First, get summary data from the ECHO_EXPORTER table.

# %%
from ECHO_modules.get_data import get_echo_data

# Get everything we will need from ECHO_EXPORTER in a single DB query.
# We can then use the full dataframe to specialize views of it.
full_echo_data = None
column_mapping = {
    '"REGISTRY_ID"': str,
    '"FAC_NAME"': str,
    '"FAC_LAT"': float,
    '"FAC_LONG"': float,
    '"AIR_IDS"': str,
    '"NPDES_IDS"': str,
    '"RCRA_IDS"': str,
    '"DFR_URL"': str,
    '"AIR_FLAG"': str,
    '"NPDES_FLAG"': str,
    '"GHG_FLAG"': str,
    '"RCRA_FLAG"': str,
    '"FAC_ACTIVE_FLAG"': str
}
column_names = list( column_mapping.keys() )
columns_string = ','.join( column_names )
sql = 'select ' + columns_string + ' from "ECHO_EXPORTER" where "AIR_FLAG" = \'Y\' or "NPDES_FLAG" = \'Y\' or "GHG_FLAG" = \'Y\' or "RCRA_FLAG" = \'Y\''
try:
    # Don't index.
    full_echo_data = get_echo_data( sql )
except EmptyDataError:
    print("\nThere are no EPA facilities for this query.\n")
full_echo_data
# Out:
#           REGISTRY_ID                  FAC_NAME    FAC_LAT    FAC_LONG  \
# 0        1.100465e+11        TIMELINE LOGISTICS        NaN         NaN
# 1        1.100712e+11                 PNR - 415  36.097744  -95.962657
# 2        1.100712e+11              MUNSON PLANT  31.158936 -101.096615
# 3        1.100178e+11         CHEM SECURITY LTD        NaN         NaN
# 4        1.100669e+11                   UNKNOWN  38.498546  -98.383430
# ...               ...                       ...        ...         ...
# 2266607  1.100669e+11                   UNKNOWN  38.498546  -98.383430
# 2266608  1.100712e+11                WD 143 A/B  28.661714  -89.551313
# 2266609  1.100708e+11  MCKINNEY TRAILER RENTALS  34.041704 -117.989254
# 2266610  1.100712e+11     BTA 430 PERMIAN BASIN  31.990559 -102.080113
# 2266611  1.100714e+11             SS 72 J/LQ/OF  28.954091  -90.960667
#
#         AIR_IDS  NPDES_IDS                   RCRA_IDS  \
# 0           NaN        NaN               NDC000009902
# 1           NaN        NaN                        NaN
# 2           NaN        NaN                        NaN
# 3           NaN        NaN               WAD980976484
# 4           NaN  KSR102460                        NaN
# ...         ...        ...                        ...
# 2266607     NaN  KSR104511                        NaN
# 2266608     NaN        NaN                        NaN
# 2266609     NaN        NaN  CAC003071892 CAL000455247
# 2266610     NaN        NaN                        NaN
# 2266611     NaN        NaN                        NaN
#
#                                                    DFR_URL AIR_FLAG  \
# 0        http://echo.epa.gov/detailed-facility-report?f...        N
# 1        http://echo.epa.gov/detailed-facility-report?f...        N
# 2        http://echo.epa.gov/detailed-facility-report?f...        N
# 3        http://echo.epa.gov/detailed-facility-report?f...        N
# 4        http://echo.epa.gov/detailed-facility-report?f...        N
# ...                                                    ...      ...
# 2266607  http://echo.epa.gov/detailed-facility-report?f...        N
# 2266608  http://echo.epa.gov/detailed-facility-report?f...        N
# 2266609  http://echo.epa.gov/detailed-facility-report?f...        N
# 2266610  http://echo.epa.gov/detailed-facility-report?f...        N
# 2266611  http://echo.epa.gov/detailed-facility-report?f...        N
#
#         NPDES_FLAG GHG_FLAG RCRA_FLAG FAC_ACTIVE_FLAG
# 0                N        N         Y             NaN
# 1                N        Y         N             NaN
# 2                N        Y         N             NaN
# 3                N        N         Y             NaN
# 4                Y        N         N             NaN
# ...            ...      ...       ...             ...
# 2266607          Y        N         N             NaN
# 2266608          N        Y         N             NaN
# 2266609          N        N         Y             NaN
# 2266610          N        Y         N             NaN
# 2266611          N        Y         N             NaN
#
# [2266612 rows x 13 columns]

# %% [markdown]
# ## Number of Currently Regulated Facilities Per Program

# %%
air_fac = full_echo_data.loc[(full_echo_data["AIR_FLAG"]=="Y") & (full_echo_data["FAC_ACTIVE_FLAG"]=="Y")].shape[0]
water_fac = full_echo_data.loc[(full_echo_data["NPDES_FLAG"]=="Y") & (full_echo_data["FAC_ACTIVE_FLAG"]=="Y")].shape[0]
waste_fac = full_echo_data.loc[(full_echo_data["RCRA_FLAG"]=="Y") & (full_echo_data["FAC_ACTIVE_FLAG"]=="Y")].shape[0]
ghg_fac = full_echo_data.loc[(full_echo_data["GHG_FLAG"]=="Y") & (full_echo_data["FAC_ACTIVE_FLAG"]=="Y")].shape[0]

display(HTML("<h3>There are "+ str(air_fac) + " facilities currently regulated under the Clean Air Act.</h3>"))
display(HTML("<h3>There are "+ str(water_fac) + " facilities currently regulated under the Clean Water Act.</h3>"))
display(HTML("<h3>There are "+ str(waste_fac) + " facilities currently regulated under RCRA (hazardous waste).</h3>"))
display(HTML("<h3>There are "+ str(ghg_fac) + " facilities currently reporting greenhouse gas emissions.</h3>"))
# Out:
# <h3>There are 195044 facilities currently regulated under the Clean Air Act.</h3>
# <h3>There are 452766 facilities currently regulated under the Clean Water Act.</h3>
# <h3>There are 625812 facilities currently regulated under RCRA (hazardous waste).</h3>
# <h3>There are 5275 facilities currently reporting greenhouse gas emissions.</h3>

# %% [markdown]
# ## Clean Air Act inspections in 2023

# %%
# Use SQL to search for and select the data about air stack tests
air_inspections = None
try:
    sql = 'select * from \"ICIS-AIR_FCES_PCES\" where \"ACTUAL_END_DATE\" like \'__-__-2023\''

    # Download the data from that URL
    air_inspections = get_echo_data( sql, 'pgm_sys_id' )
except EmptyDataError:
    print( "No data found")

air_inspections
# Out:
#                PGM_SYS_ID  ACTIVITY_ID STATE_EPA_FLAG ACTIVITY_TYPE_CODE  \
# 0      020000003606501000   3603525833              E                INS
# 1       02000110006908383   3603670421              E                INS
# 2         03000000WV00005   3603637422              E                INS
# 3         03000000WV00006   3603640498              E                INS
# 4            03000PA00013   3603577661              E                INS
# ...                   ...          ...            ...                ...
# 37872       WV00005100142   3603751040              S                INS
# 37873       WV00005100145   3603773378              S                INS
# 37874       WV00005100125   3603773364              S                INS
# 37875  MO0000002951000016   3603753773              E                INS
# 37876  NE0000003116700002   3603711670              E                INS
#
#           ACTIVITY_TYPE_DESC COMP_MONITOR_TYPE_CODE COMP_MONITOR_TYPE_DESC  \
# 0      Inspection/Evaluation                    FOO            FCE On-Site
# 1      Inspection/Evaluation                    PFF           PCE Off-Site
# 2      Inspection/Evaluation                    FOO            FCE On-Site
# 3      Inspection/Evaluation                    FOO            FCE On-Site
# 4      Inspection/Evaluation                    PFF           PCE Off-Site
# ...                      ...                    ...                    ...
# 37872  Inspection/Evaluation                    FOO            FCE On-Site
# 37873  Inspection/Evaluation                    FOO            FCE On-Site
# 37874  Inspection/Evaluation                    FOO            FCE On-Site
# 37875  Inspection/Evaluation                    PCE            PCE On-Site
# 37876  Inspection/Evaluation                    PCE            PCE On-Site
#
#       ACTUAL_END_DATE                    PROGRAM_CODES
# 0          02-15-2023  CAAMACT, CAANSPS, CAAOP, CAATIP
# 1          06-28-2023          CAAMACT, CAANSPS, CAASO
# 2          06-27-2023       CAAGACTM, CAAMACT, CAANSPS
# 3          06-28-2023                          CAAFENF
# 4          04-20-2023                           CAAIRM
# ...               ...                              ...
# 37872      09-28-2023        CAAGACTM, CAANSPS, CAASIP
# 37873      09-21-2023         CAAMACT, CAANSPS, CAASIP
# 37874      09-20-2023                  CAANSPS, CAASIP
# 37875      09-25-2023                              NaN
# 37876      08-24-2023                              NaN
#
# [37877 rows x 9 columns]

# %%
# Number of inspections in 2023 per 1000 regulated facilities
air_inspections_metric = formatter((air_inspections.shape[0] / air_fac) * 1000) # Divide by regulated facilities and multiply by desired rate (per 1000)
inspections["CAA"] = air_inspections_metric
display(HTML("<h3>"+ air_inspections_metric +" inspections per 1000 facilities</h3>"))
# Out:
# <h3>194.20 inspections per 1000 facilities</h3>

# %% [markdown]
# ## Violations of the Clean Air Act in 2023

# %%
air_violations = None
try:
    sql = 'select * from "ICIS-AIR_VIOLATION_HISTORY" where "EARLIEST_FRV_DETERM_DATE" like \'__-__-2023\' or "HPV_DAYZERO_DATE" like \'__-__-2023\''

    air_violations = get_echo_data( sql, "pgm_sys_id" )

    # Optional: remove "FACIL" violations, which are paperwork violations according to: https://19january2017snapshot.epa.gov/sites/production/files/2013-10/documents/frvmemo.pdf
    # air_violations = air_violations.loc[(air_violations["POLLUTANT_DESCS"]!="FACIL")]
except EmptyDataError:
    print( "No data found")
air_violations
# Out:
#               PGM_SYS_ID  ACTIVITY_ID AGENCY_TYPE_DESC STATE_CODE  \
# 0     CT0000000900308899   3603697029            State         CT
# 1     CT0000000900309016   3603578518            State         CT
# 2         IL000119813AAI   3603596439            State         IL
# 3     IN0000001803900097   3603489144            State         IN
# 4     IN0000001803300043   3603672177            State         IN
# ...                  ...          ...              ...        ...
# 3391  OH0000001318008977   3603753861            State         OH
# 3392  OH0000000247102007   3603748298            State         OH
# 3393  MI00000000000P1318   3603752497            State         MI
# 3394         PA000860825   3603753520            State         PA
# 3395  WI0000005508102842   3603776000            State         WI
#
#      AIR_LCON_CODE     COMP_DETERMINATION_UID ENF_RESPONSE_POLICY_CODE  \
# 0              NaN               CT000A102337                      FRV
# 1              NaN               CT000A100134                      FRV
# 2              NaN         IL000AA-2022-00162                      FRV
# 3              NaN                IN000A98533                      FRV
# 4              NaN               IN000A101809                      HPV
# ...            ...                        ...                      ...
# 3391           NaN               OH000AC13785                      FRV
# 3392           NaN               OH000AC13780                      HPV
# 3393           NaN    MI000AP1318CF0000077251                      FRV
# 3394           NaN  PA000A0000F00000003567289                      FRV
# 3395           NaN  WI000A0000550810284200503                      FRV
#
#         PROGRAM_CODES                                      PROGRAM_DESCS  \
# 0              CAASIP  State Implementation Plan for National Primary...
# 1              CAANSR              New Source Review Permit Requirements
# 2       CAASIP CAATVP  State Implementation Plan for National Primary...
# 3              CAATVP                                    Title V Permits
# 4              CAATVP                                    Title V Permits
# ...               ...                                                ...
# 3391           CAASIP  State Implementation Plan for National Primary...
# 3392  CAAFESOP CAASIP  Federally-Enforceable State Operating Permit -...
# 3393    CAANSR CAASIP  New Source Review Permit Requirements State Im...
# 3394           CAASIP  State Implementation Plan for National Primary...
# 3395           CAASIP  State Implementation Plan for National Primary...
#
#           POLLUTANT_CODES                                    POLLUTANT_DESCS  \
# 0               300000329                                              FACIL
# 1               300000243                  VOLATILE ORGANIC COMPOUNDS (VOCS)
# 2     300000319 300000320  PARTICULATE MATTER < 10 UM PARTICULATE MATTER ...
# 3               300000329                                              FACIL
# 4               300000036                                            Mercury
# ...                   ...                                                ...
# 3391            300000329                                              FACIL
# 3392            300000329                                              FACIL
# 3393            300000329                                              FACIL
# 3394            300000329                                              FACIL
# 3395            300000329                                              FACIL
#
#      EARLIEST_FRV_DETERM_DATE HPV_DAYZERO_DATE HPV_RESOLVED_DATE
# 0                  06-20-2023              NaN               NaN
# 1                  04-19-2023              NaN               NaN
# 2                  02-08-2023              NaN               NaN
# 3                  01-25-2023              NaN               NaN
# 4                  05-22-2023       08-20-2023               NaN
# ...                       ...              ...               ...
# 3391               10-16-2023              NaN               NaN
# 3392               10-03-2023       10-03-2023               NaN
# 3393               08-22-2023              NaN               NaN
# 3394               06-06-2023              NaN               NaN
# 3395               07-31-2023              NaN        08-02-2023
#
# [3396 rows x 14 columns]

# %%
# Number of high priority and federally reportable violations per 1000 regulated facilities
air_violations_metric = formatter((air_violations.shape[0] / air_fac) * 1000) # Divide by regulated facilities and multiply by desired rate (per 1000)
violations["CAA"] = air_violations_metric
display(HTML("<h3>"+air_violations_metric+" violations per 1000 facilities </h3>"))
# Out:
# <h3>17.41 violations per 1000 facilities </h3>

# %% [markdown]
# ## Formal Enforcement Actions and Penalties under the Clean Air Act in 2023

# %%
air_enforcements = None
try:
    sql = 'select * from "ICIS-AIR_FORMAL_ACTIONS" where "SETTLEMENT_ENTERED_DATE" like \'__/__/2023\''

    air_enforcements = get_echo_data( sql, "pgm_sys_id" )
except EmptyDataError:
    print( "No data found")
air_enforcements
# Out:
#               PGM_SYS_ID  ACTIVITY_ID             ENF_IDENTIFIER  \
# 0     ID0000001605500122   3603585412            ID000A200223766
# 1     TX0000004835500003   3602956335      TX000A389500382021341
# 2     CABAA00006013B1911   3602109137            CABAAA200182432
# 3         IL000037803AAF   3602227606  IL000ACM20200630105737114
# 4     TX0000004836100014   3602226809      TX000A149515062020176
# ...                  ...          ...                        ...
# 2047  IN0000001803900283   3603721887            IN000A200228607
# 2048  CASJV00006099N1662   3603718642  CASJVA3000000000000011868
# 2049  IN0000001809100163   3603747719            IN000A200229176
# 2050  OK0000004004500604   3603721543  OK000A4004500604E00130399
# 2051  DE0000001000300622   3603624623  DE000A0000100030062200025
#
#      ACTIVITY_TYPE_CODE       ACTIVITY_TYPE_DESC STATE_EPA_FLAG ENF_TYPE_CODE  \
# 0                   AFR  Administrative - Formal              S        SCAAAO
# 1                   AFR  Administrative - Formal              S        SCAAAO
# 2                   AFR  Administrative - Formal              L        SCAAAO
# 3                   JDC                 Judicial              S           CIV
# 4                   AFR  Administrative - Formal              S        SCAAAO
# ...                 ...                      ...            ...           ...
# 2047                AFR  Administrative - Formal              S        SCAAAO
# 2048                AFR  Administrative - Formal              L        SCAAAO
# 2049                AFR  Administrative - Formal              S        SCAAAO
# 2050                AFR  Administrative - Formal              S        SCAAAO
# 2051                AFR  Administrative - Formal              S        SCAAAO
#
#               ENF_TYPE_DESC SETTLEMENT_ENTERED_DATE  PENALTY_AMOUNT
# 0      Administrative Order              04/27/2023          2250.0
# 1      Administrative Order              08/07/2023         13563.0
# 2      Administrative Order              01/05/2023             0.0
# 3     Civil Judicial Action              06/01/2023         75000.0
# 4      Administrative Order              03/13/2023         13200.0
# ...                     ...                     ...             ...
# 2047   Administrative Order              09/05/2023         12400.0
# 2048   Administrative Order              07/31/2023             0.0
# 2049   Administrative Order              09/18/2023           500.0
# 2050   Administrative Order              09/14/2023          3500.0
# 2051   Administrative Order              05/26/2023             0.0
#
# [2052 rows x 10 columns]

# %%
# Number of formal actions in 2023 per violation
air_enforcements_metric = formatter(air_enforcements.shape[0]/air_violations.shape[0]) # Formal actions divided by number of violations
enforcements["CAA"] = air_enforcements_metric
display(HTML("<h3>"+air_enforcements_metric +" formal enforcement actions per violation</h3>"))
# Out:
# <h3>0.60 formal enforcement actions per violation</h3>

# %%
# Penalties each year per violating facility
air_penalties = air_enforcements.loc[air_enforcements["PENALTY_AMOUNT"]>0]
air_penalties_metric = formatter(sum(air_penalties["PENALTY_AMOUNT"]) / len(air_violations["PGM_SYS_ID"].unique())) #Divide the sum of penalties by number of violating facilities
air_penalties_max = formatter(max(air_penalties["PENALTY_AMOUNT"]))
air_penalties_min = formatter(min(air_penalties["PENALTY_AMOUNT"]))
penalties["CAA"] = air_penalties_metric
display(HTML("<h3>$"+air_penalties_metric +" per facility in violation</h3>"))
display(HTML("<h3>Max: $"+air_penalties_max +"</h3>"))
display(HTML("<h3>Min: $"+air_penalties_min +"</h3>"))
# Out:
# <h3>$136009.23 per facility in violation</h3>
# <h3>Max: $40336818.00</h3>
# <h3>Min: $100.00</h3>

# %% [markdown]
# ---

# %% [markdown]
# ## Clean Water Act inspections in 2023

# %%
# Find facilities with pollutant exceedences
water_inspections = None
try:
    sql = 'select "NPDES_ID", "REGISTRY_ID", "ACTUAL_END_DATE", "STATE_EPA_FLAG"' + \
        ' from "NPDES_INSPECTIONS" where "ACTUAL_END_DATE" like \'__/__/2023\''

    water_inspections = get_echo_data( sql, "NPDES_ID" )
except EmptyDataError:
    print( "No data found")
water_inspections
# Out:
#             REGISTRY_ID ACTUAL_END_DATE STATE_EPA_FLAG
# NPDES_ID
# FLR05G764  110000365603      04/18/2023              S
# PAC480072  110070563506      05/19/2023              S
# VTS006835  110071221209      05/10/2023              S
# UTRC04044  110071181513      04/28/2023              S
# FLR20CY73  110058278091      05/05/2023              S
# ...                 ...             ...            ...
# FLG110637  110033170226      05/08/2023              S
# OH0123595  110000840225      09/27/2023              S
# OH0136247  110027372714      08/29/2023              S
# VAG750207  110070563313      09/14/2023              S
# HIU010711  110071435465      06/21/2023              S
#
# [43133 rows x 3 columns]

# %%
# Number of inspections in 2023 per 1000 regulated facilities
water_inspections_metric = formatter((water_inspections.shape[0] / water_fac) * 1000) #Divide by regulated facilities and multiply by desired rate (per 1000)
inspections["CWA"] = water_inspections_metric
display(HTML("<h3>"+water_inspections_metric +" inspections per 1000 facilities</h3>"))
# Out:
# <h3>95.27 inspections per 1000 facilities</h3>

# %% [markdown]
# ## Violations of the Clean Water Act in 2023

# %%
# Find facilities with water permit violations
water_violations = None
try:
    sql = 'select * from "NPDES_QNCR_HISTORY" where "YEARQTR" = 20231 or "YEARQTR" = 20232 or "YEARQTR" = 20233 or "YEARQTR" = 20234'
    water_violations = get_echo_data( sql, "NPDES_ID" )
except EmptyDataError:
    print( "No data found")
water_violations
# Out:
#            YEARQTR HLRNC  NUME90Q  NUMCVDT  NUMSVCD  NUMPSCH
# NPDES_ID
# AK0001058    20231              0        0        0        3
# AK0001058    20232              0        0        0        3
# AK0001058    20233              0        0        0        3
# AK0000272    20234              1        0        0        0
# AK0000345    20231              0        0        0        2
# ...            ...   ...      ...      ...      ...      ...
# WY0096113    20231     R        0        0        2        0
# WY0096113    20232     V        0        0        2        0
# WY0096113    20233     V        1        0        2        0
# WY0096113    20234     V        0        0        0        0
# WY0096121    20231     U        0        0        0        0
#
# [342094 rows x 6 columns]

# %%
# Number of violations each year per 1000 regulated facilities
# Sum violations
water_violations["Sum"] = water_violations["NUME90Q"]	+ water_violations["NUMCVDT"] + water_violations["NUMSVCD"]	+ water_violations["NUMPSCH"]
water_violations_metric = formatter((np.sum(water_violations["Sum"]) / water_fac) * 1000) #Divide by regulated facilities and multiply by desired rate (per 1000)
violations["CWA"] = water_violations_metric
display(HTML("<h3>"+water_violations_metric+" violations per 1000 facilities</h3>"))
# Out:
# <h3>856.61 violations per 1000 facilities</h3>

# %% [markdown]
# ## Enforcement Actions and Penalties under the Clean Water Act in 2023

# %%
# Find facilities with pollutant exceedences
water_enforcements = None
try:
    sql = 'select "NPDES_ID", "AGENCY", "ENF_TYPE_DESC", "SETTLEMENT_ENTERED_DATE", "FED_PENALTY_ASSESSED_AMT", "STATE_LOCAL_PENALTY_AMT"' + \
        ' from "NPDES_FORMAL_ENFORCEMENT_ACTIONS" where "SETTLEMENT_ENTERED_DATE" like \'__/__/2023\''

    water_enforcements = get_echo_data( sql, "NPDES_ID" )
except EmptyDataError:
    print( "No data found")
water_enforcements
# Out:
#           AGENCY                          ENF_TYPE_DESC  \
# NPDES_ID
# TXR05CG16    EPA                  Civil Judicial Action
# PAR803556    EPA                  Civil Judicial Action
# PAR800080    EPA                  Civil Judicial Action
# PAR802229    EPA                  Civil Judicial Action
# ILR001339    EPA                  Civil Judicial Action
# ...          ...                                    ...
# NC0021181  State                   State CWA Penalty AO
# NC0024881  State                   State CWA Penalty AO
# OKR040021  State               State CWA Non Penalty AO
# NYR00G297  State  State Administrative Order of Consent
# TXR1572KG  State                   State CWA Penalty AO
#
#           SETTLEMENT_ENTERED_DATE  FED_PENALTY_ASSESSED_AMT  \
# NPDES_ID
# TXR05CG16              09/14/2023                  483064.0
# PAR803556              09/14/2023                  483064.0
# PAR800080              09/14/2023                  483064.0
# PAR802229              09/14/2023                  483064.0
# ILR001339              09/14/2023                  483064.0
# ...                           ...                       ...
# NC0021181              10/16/2023                       NaN
# NC0024881              10/26/2023                       NaN
# OKR040021              10/31/2023                       NaN
# NYR00G297              09/25/2023                       NaN
# TXR1572KG              10/31/2023                       NaN
#
#            STATE_LOCAL_PENALTY_AMT
# NPDES_ID
# TXR05CG16                 51936.00
# PAR803556                 51936.00
# PAR800080                 51936.00
# PAR802229                 51936.00
# ILR001339                 51936.00
# ...                            ...
# NC0021181                  2933.03
# NC0024881                  1053.14
# OKR040021                      NaN
# NYR00G297                  2600.00
# TXR1572KG                   875.00
#
# [2522 rows x 5 columns]

# %%
# Number of formal actions in 2023 per violation
water_enforcements_metric = formatter(water_enforcements.shape[0]/water_violations.shape[0]) # Formal actions divided by number of violations
enforcements["CWA"] = water_enforcements_metric
display(HTML("<h3>"+water_enforcements_metric +" formal enforcement actions per violation</h3>"))
# Out:
# <h3>0.01 formal enforcement actions per violation</h3>

# %%
# Penalties each year per violating facility
# Find violating facilities (not all in NPDES QNCR are violating...)
water_violators = water_violations.loc[water_violations["Sum"]>0]
water_violators = len(water_violators.index.unique())
water_enforcements["StateLocalFedFines"] = water_enforcements["FED_PENALTY_ASSESSED_AMT"].fillna(0) + water_enforcements["STATE_LOCAL_PENALTY_AMT"].fillna(0)
water_penalties = water_enforcements.loc[water_enforcements["StateLocalFedFines"]>0]
water_penalties_metric = formatter(sum(water_penalties["StateLocalFedFines"]) / water_violators) #Divide the sum of penalties by number of penalized facilities
water_penalties_max = formatter(max(water_penalties["StateLocalFedFines"]))
water_penalties_min = formatter(min(water_penalties["StateLocalFedFines"]))
penalties["CWA"] = water_penalties_metric
display(HTML("<h3>$"+water_penalties_metric +" per facility in violation</h3>"))
display(HTML("<h3>Max: $"+water_penalties_max +"</h3>"))
display(HTML("<h3>Min: $"+water_penalties_min +"</h3>"))
# Out:
# <h3>$2002.27 per facility in violation</h3>
# <h3>Max: $2423728.00</h3>
# <h3>Min: $138.85</h3>

# %% [markdown]
# ## RCRA inspections in 2023

# %%
# Find facilities with pollutant exceedences
waste_inspections = None
try:
    sql = 'select * from "RCRA_EVALUATIONS" where "EVALUATION_START_DATE" like \'__/__/2023\''

    waste_inspections = get_echo_data( sql, "ID_NUMBER" )
except EmptyDataError:
    print( "No data found")
waste_inspections
# Out:
#              ACTIVITY_LOCATION EVALUATION_IDENTIFIER EVALUATION_TYPE  \
# ID_NUMBER
# NVR000033738                NV                   001             CEI
# IDR000205732                ID                   001             CAV
# TND982165136                TN                   001             CEI
# NYR000076901                NY                   001             CEI
# WVD988786455                WV                   001             CEI
# ...                        ...                   ...             ...
# TXD007325087                TX                     2             CEI
# KYR000032888                KY                   001             CEI
# NCD980842132                NC                   395             FCI
# NCD980842132                NC                   395             FCI
# TXD008129983                TX                    22             FCI
#
#                                EVALUATION_DESC EVALUATION_AGENCY  \
# ID_NUMBER
# NVR000033738  COMPLIANCE EVALUATION INSPECTION               S
# IDR000205732       COMPLIANCE ASSISTANCE VISIT               S
# TND982165136  COMPLIANCE EVALUATION INSPECTION               S
# NYR000076901  COMPLIANCE EVALUATION INSPECTION               S
# WVD988786455  COMPLIANCE EVALUATION INSPECTION               S
# ...                                        ...               ...
# TXD007325087  COMPLIANCE EVALUATION INSPECTION               S
# KYR000032888  COMPLIANCE EVALUATION INSPECTION               S
# NCD980842132     FOCUSED COMPLIANCE INSPECTION               S
# NCD980842132     FOCUSED COMPLIANCE INSPECTION               S
# TXD008129983     FOCUSED COMPLIANCE INSPECTION               S
#
#              EVALUATION_START_DATE FOUND_VIOLATION
# ID_NUMBER
# NVR000033738            06/29/2023             N
# IDR000205732            06/27/2023             N
# TND982165136            06/28/2023             Y
# NYR000076901            06/30/2023             Y
# WVD988786455            04/04/2023             Y
# ...                            ...             ...
# TXD007325087            08/17/2023             N
# KYR000032888            10/03/2023             Y
# NCD980842132            10/19/2023             N
# NCD980842132            10/31/2023             N
# TXD008129983            06/23/2023             N
#
# [15898 rows x 7 columns]

# %%
# Number of inspections in 2023 per 1000 regulated facilities
waste_inspections_metric = formatter((waste_inspections.shape[0] / waste_fac) * 1000) #Divide by regulated facilities and multiply by desired rate (per 1000)
inspections["RCRA"] = waste_inspections_metric
display(HTML("<h3>"+waste_inspections_metric+" inspections per 1000 facilities</h3>"))
# Out:
# <h3>25.40 inspections per 1000 facilities</h3>

# %% [markdown]
# ## Violations of RCRA in 2023

# %%
# Find facilities with pollutant exceedences
waste_violations = None
try:
    sql = 'select * from "RCRA_VIOLATIONS" where "DATE_VIOLATION_DETERMINED" like \'__/__/2023\''

    waste_violations = get_echo_data( sql, "ID_NUMBER" )
except EmptyDataError:
    print( "No data found")
waste_violations
# Out:
#              ACTIVITY_LOCATION VIOLATION_TYPE  \
# ID_NUMBER
# MID005340161                MI          273.B
# CAL000403861                CA          262.B
# CAR000245050                CA          263.A
# MID017053844                MI            XXS
# MIK568288583                MI            XXS
# ...                        ...            ...
# WI0000361501                WI          262.M
# FLR000136523                FL          279.C
# FLR000143891                FL            PCR
# FLR000073296                FL          262.A
# WIR000051417                WI          262.A
#
#                                             VIOLATION_TYPE_DESC  \
# ID_NUMBER
# MID005340161  Standards for Universal Waste Management: Stan...
# CAL000403861  Standards Applicable to Generators of HW: Mani...
# CAR000245050  Standards Applicable to Transporters of HW: Ge...
# MID017053844  State Statutory or Regulatory requirements tha...
# MIK568288583  State Statutory or Regulatory requirements tha...
# ...                                                         ...
# WI0000361501  Standards Applicable to Generators of HW: Prep...
# FLR000136523                 Standards for Used Oil: Generators
# FLR000143891     Violation of a permit condition or requirement
# FLR000073296  Standards Applicable to Generators of HW: General
# WIR000051417  Standards Applicable to Generators of HW: General
#
#              VIOL_DETERMINED_BY_AGENCY DATE_VIOLATION_DETERMINED  \
# ID_NUMBER
# MID005340161                       S                  05/25/2023
# CAL000403861                       S                  07/27/2023
# CAR000245050                       S                  05/31/2023
# MID017053844                       S                  04/20/2023
# MIK568288583                       S                  05/10/2023
# ...                                ...                       ...
# WI0000361501                       S                  02/28/2023
# FLR000136523                       S                  02/07/2023
# FLR000143891                       S                  02/22/2023
# FLR000073296                       S                  02/09/2023
# WIR000051417                       S                  01/24/2023
#
#              ACTUAL_RTC_DATE SCHEDULED_COMPLIANCE_DATE
# ID_NUMBER
# MID005340161             NaN                       NaN
# CAL000403861      07/28/2023                       NaN
# CAR000245050      07/11/2023                       NaN
# MID017053844      05/17/2023                       NaN
# MIK568288583      06/01/2023                       NaN
# ...                      ...                       ...
# WI0000361501      04/26/2023                       NaN
# FLR000136523      05/18/2023                       NaN
# FLR000143891      03/17/2023                       NaN
# FLR000073296      05/18/2023                       NaN
# WIR000051417      01/24/2023                       NaN
#
# [9896 rows x 7 columns]

# %%
# Number of violations in 2023 per 1000 regulated facilities
waste_violations_metric = formatter((waste_violations.shape[0] / waste_fac) * 1000) #Divide by regulated facilities and multiply by desired rate (per 1000)
violations["RCRA"] = waste_violations_metric
display(HTML("<h3>"+waste_violations_metric+" violations per 1000 facilities</h3>"))
# Out:
# <h3>15.81 violations per 1000 facilities</h3>

# %% [markdown]
# ## Enforcement Actions and Penalties under RCRA in 2023

# %%
# Find facilities with enforcement actions
waste_enforcements = None
try:
    sql = 'select * from "RCRA_ENFORCEMENTS" where "ENFORCEMENT_ACTION_DATE" like \'__/__/2023\''

    waste_enforcements = get_echo_data( sql, "ID_NUMBER" )
except EmptyDataError:
    print( "No data found")
waste_enforcements
# Out:
#              ACTIVITY_LOCATION ENFORCEMENT_IDENTIFIER ENFORCEMENT_TYPE  \
# ID_NUMBER
# KYR000006874                KY                    001            HQ120
# INR000130088                IN                    003            HQ120
# ALR000062588                AL                    001            HQ120
# IAD078096732                IA                    001            HQ305
# SCR000776526                SC                    001            HQ310
# ...                        ...                    ...              ...
# INT190014381                IN                    002            HQ120
# OHR000221846                OH                    001            HQ120
# DCR000502682                DC                    001            HQ120
# NYD986909026                NY                    001            HQ120
# ALR000005025                AL                    001            AL115
#
#                                     ENFORCEMENT_DESC ENFORCEMENT_AGENCY  \
# ID_NUMBER
# KYR000006874                        WRITTEN INFORMAL                S
# INR000130088                        WRITTEN INFORMAL                S
# ALR000062588                        WRITTEN INFORMAL                S
# IAD078096732  3008(a) EXPEDITED SETTLEMENT AGREEMENT                E
# SCR000776526          FINAL 3008(A) COMPLIANCE ORDER                S
# ...                                              ...                ...
# INT190014381                        WRITTEN INFORMAL                S
# OHR000221846                        WRITTEN INFORMAL                S
# DCR000502682                        WRITTEN INFORMAL                S
# NYD986909026                        WRITTEN INFORMAL                S
# ALR000005025                          WARNING LETTER                S
#
#              ENFORCEMENT_ACTION_DATE  PMP_AMOUNT  FMP_AMOUNT  FSC_AMOUNT  \
# ID_NUMBER
# KYR000006874              01/09/2023         NaN         NaN         NaN
# INR000130088              10/17/2023         NaN         NaN         NaN
# ALR000062588              05/01/2023         NaN         NaN         NaN
# IAD078096732              06/20/2023         NaN      8750.0         NaN
# SCR000776526              05/23/2023         NaN      9000.0         NaN
# ...                              ...         ...         ...         ...
# INT190014381              10/17/2023         NaN         NaN         NaN
# OHR000221846              04/24/2023         NaN         NaN         NaN
# DCR000502682              10/05/2023         NaN         NaN         NaN
# NYD986909026              02/15/2023         NaN         NaN         NaN
# ALR000005025              03/08/2023         NaN         NaN         NaN
#
#               SCR_AMOUNT
# ID_NUMBER
# KYR000006874         NaN
# INR000130088         NaN
# ALR000062588         NaN
# IAD078096732         NaN
# SCR000776526         NaN
# ...                  ...
# INT190014381         NaN
# OHR000221846         NaN
# DCR000502682         NaN
# NYD986909026         NaN
# ALR000005025         NaN
#
# [4799 rows x 10 columns]

# %%
# Number of enforcement actions each year per violation
waste_enforcements_metric = formatter(waste_enforcements.shape[0] / waste_violations.shape[0])
enforcements["RCRA"] = waste_enforcements_metric
display(HTML("<h3>"+waste_enforcements_metric+" enforcement actions per violation</h3>"))
# Out:
# <h3>0.48 enforcement actions per violation</h3>

# %%
# Penalties each year per violating facility
waste_penalties = waste_enforcements.loc[waste_enforcements["FMP_AMOUNT"]>0]
waste_penalties_metric = formatter(sum(waste_penalties["FMP_AMOUNT"]) / len(waste_violations.index.unique())) #Divide by penalized facilities
waste_penalties_max = formatter(max(waste_penalties["FMP_AMOUNT"]))
waste_penalties_min = formatter(min(waste_penalties["FMP_AMOUNT"]))
penalties["RCRA"] = waste_penalties_metric
display(HTML("<h3>$"+waste_penalties_metric +" per facility in violation</h3>"))
display(HTML("<h3>Max: $"+waste_penalties_max +"</h3>"))
display(HTML("<h3>Min: $"+waste_penalties_min +"</h3>"))
# Out:
# <h3>$2906.24 per facility in violation</h3>
# <h3>Max: $689900.00</h3>
# <h3>Min: $211.00</h3>

# %% [markdown]
# ## Greenhouse Gas Emissions in 2022 (latest data available)

# %%
# Find GHG emissions
ghg_emissions = None
try:
    sql = 'select * from "POLL_RPT_COMBINED_EMISSIONS" where "REPORTING_YEAR" = \'2022\' and "PGM_SYS_ACRNM" = \'E-GGRT\''

    ghg_emissions = get_echo_data( sql)
except EmptyDataError:
    print( "No data found")
ghg_emissions
# Out:
#        REPORTING_YEAR   REGISTRY_ID PGM_SYS_ACRNM  PGM_SYS_ID  POLLUTANT_NAME  \
# 0                2022  110030735916        E-GGRT     1008735         Methane
# 1                2022  110070716075        E-GGRT     1013663  Carbon dioxide
# 2                2022  110070716075        E-GGRT     1013663         Methane
# 3                2022  110017864890        E-GGRT     1013537  Carbon dioxide
# 4                2022  110017864890        E-GGRT     1013537         Methane
# ...               ...           ...           ...         ...             ...
# 21457            2022  110063648904        E-GGRT     1007691         Methane
# 21458            2022  110063648904        E-GGRT     1007691  Carbon dioxide
# 21459            2022  110028047209        E-GGRT     1004969   Nitrous oxide
# 21460            2022  110028047209        E-GGRT     1004969  Carbon dioxide
# 21461            2022  110028047209        E-GGRT     1004969         Methane
#
#        ANNUAL_EMISSION UNIT_OF_MEASURE  NEI_TYPE  NEI_HAP_VOC_FLAG
# 0               17.750          MTCO2e       NaN               NaN
# 1               23.100          MTCO2e       NaN               NaN
# 2            20054.500          MTCO2e       NaN               NaN
# 3            29490.500          MTCO2e       NaN               NaN
# 4               14.000          MTCO2e       NaN               NaN
# ...                ...             ...       ...               ...
# 21457         7476.750          MTCO2e       NaN               NaN
# 21458          126.400          MTCO2e       NaN               NaN
# 21459         5725.176          MTCO2e       NaN               NaN
# 21460       158599.900          MTCO2e       NaN               NaN
# 21461         3657.250          MTCO2e       NaN               NaN
#
# [21462 rows x 9 columns]

# %%
# Emissions in 2022 per facility
ghg_emissions_metric = formatter(np.nansum(ghg_emissions["ANNUAL_EMISSION"]) / len(ghg_emissions["REGISTRY_ID"].unique())) #Divide by reporting facility
ghg_emissions_fac = ghg_emissions.groupby("PGM_SYS_ID")[["ANNUAL_EMISSION"]].sum() # Group by facility
ghg_emissions_max = formatter(np.nanmax(ghg_emissions_fac["ANNUAL_EMISSION"]))
ghg_emissions_min = formatter(np.nanmin(ghg_emissions_fac.loc[ghg_emissions_fac["ANNUAL_EMISSION"]>0]["ANNUAL_EMISSION"]))
emissions["GHG"] = ghg_emissions_metric
display(HTML("<h3>"+ghg_emissions_metric+" MTCO2e (metric tons of carbon dioxide equivalent) emissions per reporting facility</h3>"))
display(HTML("<h3>Max: "+ghg_emissions_max+" MTCO2e (metric tons of carbon dioxide equivalent) emissions</h3>"))
display(HTML("<h3>Min: "+ghg_emissions_min+" MTCO2e (metric tons of carbon dioxide equivalent) emissions</h3>"))
ghg_emissions_fac
# Out:
# <h3>382474.04 MTCO2e (metric tons of carbon dioxide equivalent) emissions per reporting facility</h3>
# <h3>Max: 21775439.59 MTCO2e (metric tons of carbon dioxide equivalent) emissions</h3>
# <h3>Min: 0.10 MTCO2e (metric tons of carbon dioxide equivalent) emissions</h3>
#             ANNUAL_EMISSION
# PGM_SYS_ID
# 1000001          464785.558
# 1000002          115616.900
# 1000003           79156.516
# 1000005           76626.784
# 1000007           16693.588
# ...                     ...
# 1014727           53616.084
# 1014728           25935.722
# 1014729          130774.538
# 1014730          123149.272
# 1014737           71483.992
#
# [7586 rows x 1 columns]

# %% [markdown]
# # Data Export

# %%
data = [inspections,
violations,
enforcements,
penalties,
emissions]

units = ["#inspections per 1000",
"#violations per 1000",
"#actions per facility in violation",
"$ per facility in violation",
"amount of emissions (metric tons)"]

short_units = ["inspectionsper1000",
"violationsper1000",
"enforcementsperviolatingfacility",
"penaltiesperviolatingfacility",
"emissions2021"]

for index, program in enumerate(data):
    # create dataframe
    df = pd.DataFrame(program, index=[0]).T
    df = df.rename(columns={0: units[index]})
    filename= short_units[index]+"_All_USA_pg4_2023.csv"
    df.to_csv(filename)
    print(df)
# Out:
#      #inspections per 1000
# CAA                 194.20
# CWA                  95.27
# RCRA                 25.40
#      #violations per 1000
# CAA                 17.41
# CWA                856.61
# RCRA                15.81
#      #actions per facility in violation
# CAA                                0.60
# CWA                                0.01
# RCRA                               0.48
#      $ per facility in violation
# CAA                    136009.23
# CWA                      2002.27
# RCRA                     2906.24
#     amount of emissions (metric tons)
# GHG                         382474.04
